# %% [markdown]
# # Import dependencies

# %%
# !pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.6/dist-packages (1.4.2)

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob 
import skimage.draw

# %% [markdown]
# # Download Mask RCNN library

# %%
# !git clone https://www.github.com/matterport/Mask_RCNN.git
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
os.chdir('Mask_RCNN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT_DIR = '/content/drive/My Drive/project'

# %% [markdown]
# # Import MaskRCNN dependencies

# %%
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Create Configuration class for Detector

# %%
class DetectorConfig(Config):
    
    NAME = 'fruits'
    
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 4  # background + 3 fruit classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (16, 32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32

    STEPS_PER_EPOCH = 25
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           fruits
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                25
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Extend existing Dataset class to customize methods

# %%
class DetectorDataset(utils.Dataset):
    
    
    def load_labels(self, labels_list):
        for i, label in enumerate(labels_list):
            self.add_class('fruits', i + 1, label)
            
    def load_dataset(self, images_obj):
        for image_obj in images_obj:
            image_id = image_obj['image_id']
            image_path = image_obj['image_path']
            num_ids = image_obj['num_ids']
            polygons = image_obj['polygons']
            width = image_obj['width']
            height = image_obj['height']
            self.add_image("fruits", image_id=image_id, path=image_path,
                           width=width, height=height, polygons=polygons,num_ids=num_ids)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            cv2.rectangle(image, (x-s, y-s), (x+s, y+s), color, -1)
        elif shape == "circle":
            cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y-s),
                                (x-s/math.sin(math.radians(60)), y+s),
                                (x+s/math.sin(math.radians(60)), y+s),
                                ]], dtype=np.int32)
            cv2.fillPoly(image, points, color)
        return image

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        info = self.image_info[image_id]
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)

        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids

# %% [markdown]
# # Set root directory for training and test dataset

# %%
train_image_path = os.path.join('/content/drive/My Drive/project/input', 'train_zip')
test_image_path = os.path.join('/content/drive/My Drive/project/input', 'test_zip')

# %% [markdown]
# # Convert xml file information to dict

# %% [markdown]
# ## Download xmltodict helper dependencies

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.6/dist-packages (0.12.0)

# %% [markdown]
# ## Define labels

# %%
labels = ["apple", "banana", "orange"]

# %% [markdown]
# ## Parse a single annoation
# - Extract the dict object and convert it into cocos format

# %%
def parse_single_annotation(label_obj):
    #print(label_obj)
    name = label_obj['name']
    # Get label
    num_id = labels.index(name) + 1
    bb_box = label_obj['bndbox']
    # Extract the xmin xmax ymin and ymax of bounding box
    xmin = int(bb_box['xmin'])
    xmax = int(bb_box['xmax'])
    ymin = int(bb_box['ymin'])
    ymax = int(bb_box['ymax'])
    # Convert it into polygon format. So we need 5 points for both x and y
    all_points_x = [xmin, xmax, xmax, xmin, xmin]
    all_points_y = [ymin, ymin, ymax, ymax, ymin]
    return all_points_x, all_points_y, num_id

# %% [markdown]
# ## Parse the images and annotations and it in a single array

# %%
import xmltodict
import json
train_images = []
def transform_annotations(image_path):
    # Start the index from 100
    curr_idx = 100
    images_list = []
    # List the files in the training or test path
    for i in os.listdir(os.path.join(image_path)):
        # Get the image path
        img_path = os.path.join(image_path, i)
        split_img_path = i.split('.')
        # check if the file is a .jpg ext. We ignore .xml file as they will be parsed based on .jpg file name
        if split_img_path[1] == 'jpg':
            # Define dict key value pair required in coco dataset
            polygons = []
            num_ids = []
            # Read the image file 
            file_data = cv2.imread(img_path)
            # Get the heigh and width. OpenCV shape is in the format h, w, depth
            height, width, _ = file_data.shape
            # Open the xml file which has the same name of the image we have opened for this iteration
            with open(os.path.join(image_path, split_img_path[0] + '.xml')) as fd:
                # Load the xml -> convert xml to dict -> convert to json
                bb_file = json.loads(json.dumps(xmltodict.parse(fd.read())))
                # There are two case - bb_file['annotation']['object'] can exist as a single dict or as a list of dict.
                # Thus, we need to do a check to see whether it is a list or not.
                # If the value is a data type of list:
                if isinstance(bb_file['annotation']['object'], list):
                    # Loop through each dict in the list
                    for obj in bb_file['annotation']['object']:
                        # Parse each annotation individually
                        all_points_x, all_points_y, num_id = parse_single_annotation(obj)
                        # Append the points into polygon list
                        polygons.append({
                            'all_points_x': all_points_x,
                            'all_points_y': all_points_y
                        })
                        # Append the id into the num_ids list
                        num_ids.append(num_id)
                # If the ['object'] key only contains a dict value
                else:
                    # We just need to parse a single annotation
                    all_points_x, all_points_y, num_id = parse_single_annotation(bb_file['annotation']['object'])
                    # Append it into polygon and num_ids list
                    polygons.append({
                        'all_points_x': all_points_x,
                        'all_points_y': all_points_y
                    })
                    num_ids.append(num_id)
            # For this image, we need to create a dict to represent it and all the corresponding annotations represented by polygons and num_ids key list
            image_label = {
                'image_path': img_path,
                'image_id': curr_idx,
                'polygons': polygons,
                'num_ids': num_ids,
                'height': height,
                'width': width
            }
            curr_idx = curr_idx + 1
            # Append it into the images_list
            images_list.append(image_label)
    return images_list

# %%
print(train_image_path)
# Out:
# /content/drive/My Drive/project/input/train_zip

# %% [markdown]
# # Store annotations into the respective train and test dataset

# %% [markdown]
# ## Load the training dataset and prepare

# %%
train_images = transform_annotations(os.path.join(train_image_path, 'train'))
print(train_images[0:5])
dataset_train = DetectorDataset()
dataset_train.load_labels(labels)
dataset_train.load_dataset(train_images)
dataset_train.prepare()
# Out:
# [{'image_path': '/content/drive/My Drive/project/input/train_zip/train/apple_1.jpg', 'image_id': 100, 'polygons': [{'all_points_x': [8, 331, 331, 8, 8], 'all_points_y': [15, 15, 349, 349, 15]}], 'num_ids': [1], 'height': 349, 'width': 349}, {'image_path': '/content/drive/My Drive/project/input/train_zip/train/apple_10.jpg', 'image_id': 101, 'polygons': [{'all_points_x': [56, 1413, 1413, 56, 56], 'all_points_y': [99, 99, 1419, 1419, 99]}], 'num_ids': [1], 'height': 1500, 'width': 1500}, {'image_path': '/content/drive/My Drive/project/input/train_zip/train/apple_11.jpg', 'image_id': 102, 'polygons': [{'all_points_x': [213, 459, 459, 213, 213], 'all_points_y': [33, 33, 258, 258, 33]}, {'all_points_x': [1, 188, 188, 1, 1], 'all_points_y': [30, 30, 280, 280, 30]}, {'all_points_x': [116, 337, 337, 116, 116], 'all_points_y': [5, 5, 220, 220, 5]}], 'num_ids': [1, 1, 1], 'height': 436, 'width': 652}, {'image_path': '/content/drive/My Drive/project/input/train_zip/train/apple_12.jpg', 'image_id': 103, 'polygons': [{'all_points_x': [43, 350, 350, 43, 43], 'all_points_y': [21, 21, 353, 353, 21]}], 'num_ids': [1], 'height': 428, 'width': 450}, {'image_path': '/content/drive/My Drive/project/input/train_zip/train/apple_13.jpg', 'image_id': 104, 'polygons': [{'all_points_x': [415, 720, 720, 415, 415], 'all_points_y': [261, 261, 567, 567, 261]}, {'all_points_x': [105, 393, 393, 105, 105], 'all_points_y': [426, 426, 691, 691, 426]}, {'all_points_x': [194, 477, 477, 194, 194], 'all_points_y': [290, 290, 545, 545, 290]}], 'num_ids': [1, 1, 1], 'height': 800, 'width': 800}]

# %% [markdown]
# ## Load the test dataset and prepare

# %%
test_images = transform_annotations(os.path.join(test_image_path, 'test'))
dataset_val = DetectorDataset()
dataset_val.load_labels(labels)
dataset_val.load_dataset(test_images)
dataset_val.prepare()

# %% [markdown]
# ## Load and visualize the pixel mask for the first 5 objects

# %%
from mrcnn import visualize
for i in range(5):
    image_id = train_images[i]['image_id']
    mask, num_id = dataset_train.load_mask(i)
    img_data = cv2.imread(train_images[i]['image_path'])
    num_id = [x - 1 for x in num_id]
    visualize.display_top_masks(img_data, mask, num_id, labels)

# %% [markdown]
# # Start training

# %% [markdown]
# ## Download the coco weights

# %%
# !cd /My Drive && mkdir project
sys.path.append(ROOT_DIR)
MODEL_DIR = os.path.join(ROOT_DIR, 'logs')
# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# /bin/bash: line 0: cd: too many arguments

# %% [markdown]
# ## Create the model with the specified configuration defined at the top of the file

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead

# %% [markdown]
# ## Load the weights of the COCO dataset

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %% [markdown]
# ## Now we can start training the actual dataset

# %%
# Train the head branches
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=30, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/My Drive/project/logs/fruits20200330T1703/mask_rcnn_fruits_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/30
# 25/25 [==============================] - 135s 5s/step - loss: 2.9223 - rpn_class_loss: 0.0167 - rpn_bbox_loss: 0.6771 - mrcnn_class_loss: 0.6065 - mrcnn_bbox_loss: 0.8466 - mrcnn_mask_loss: 0.7754 - val_loss: 1.7666 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.5172 - val_mrcnn_class_loss: 0.2910 - val_mrcnn_bbox_loss: 0.4841 - val_mrcnn_mask_loss: 0.4598
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1265: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/30
# 25/25 [==============================] - 27s 1s/step - loss: 1.5874 - rpn_class_loss: 0.0126 - rpn_bbox_loss: 0.4484 - mrcnn_class_loss: 0.2856 - mrcnn_bbox_loss: 0.4352 - mrcnn_mask_loss: 0.4056 - val_loss: 1.3988 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.4484 - val_mrcnn_class_loss: 0.2089 - val_mrcnn_bbox_loss: 0.3870 - val_mrcnn_mask_loss: 0.3426
# Epoch 3/30
# 25/25 [==============================] - 74s 3s/step - loss: 1.3096 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.4165 - mrcnn_class_loss: 0.1810 - mrcnn_bbox_loss: 0.3481 - mrcnn_mask_loss: 0.3533 - val_loss: 1.3750 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.4538 - val_mrcnn_class_loss: 0.2291 - val_mrcnn_bbox_loss: 0.3521 - val_mrcnn_mask_loss: 0.3290
# Epoch 4/30
# 25/25 [==============================] - 128s 5s/step - loss: 1.1986 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.3449 - mrcnn_class_loss: 0.2122 - mrcnn_bbox_loss: 0.3015 - mrcnn_mask_loss: 0.3308 - val_loss: 1.2723 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.3981 - val_mrcnn_class_loss: 0.2132 - val_mrcnn_bbox_loss: 0.3481 - val_mrcnn_mask_loss: 0.3026
# Epoch 5/30
# 25/25 [==============================] - 89s 4s/step - loss: 1.2330 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.3670 - mrcnn_class_loss: 0.2532 - mrcnn_bbox_loss: 0.3120 - mrcnn_mask_loss: 0.2924 - val_loss: 1.2513 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3707 - val_mrcnn_class_loss: 0.2717 - val_mrcnn_bbox_loss: 0.3037 - val_mrcnn_mask_loss: 0.2954
# Epoch 6/30
# 25/25 [==============================] - 98s 4s/step - loss: 1.1479 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.3007 - mrcnn_class_loss: 0.2620 - mrcnn_bbox_loss: 0.2572 - mrcnn_mask_loss: 0.3188 - val_loss: 1.2533 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3842 - val_mrcnn_class_loss: 0.2767 - val_mrcnn_bbox_loss: 0.3036 - val_mrcnn_mask_loss: 0.2791
# Epoch 7/30
# 25/25 [==============================] - 96s 4s/step - loss: 0.9529 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.2476 - mrcnn_class_loss: 0.2253 - mrcnn_bbox_loss: 0.2016 - mrcnn_mask_loss: 0.2719 - val_loss: 1.2695 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.4506 - val_mrcnn_class_loss: 0.2468 - val_mrcnn_bbox_loss: 0.2816 - val_mrcnn_mask_loss: 0.2800
# Epoch 8/30
# 25/25 [==============================] - 92s 4s/step - loss: 0.9912 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.2467 - mrcnn_class_loss: 0.2435 - mrcnn_bbox_loss: 0.2133 - mrcnn_mask_loss: 0.2802 - val_loss: 1.1974 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3756 - val_mrcnn_class_loss: 0.2660 - val_mrcnn_bbox_loss: 0.2782 - val_mrcnn_mask_loss: 0.2685
# Epoch 9/30
# 25/25 [==============================] - 95s 4s/step - loss: 0.9383 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.2420 - mrcnn_class_loss: 0.2218 - mrcnn_bbox_loss: 0.1904 - mrcnn_mask_loss: 0.2769 - val_loss: 1.2198 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.3916 - val_mrcnn_class_loss: 0.2717 - val_mrcnn_bbox_loss: 0.2731 - val_mrcnn_mask_loss: 0.2741
# Epoch 10/30
# 25/25 [==============================] - 99s 4s/step - loss: 0.9213 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.2275 - mrcnn_class_loss: 0.2323 - mrcnn_bbox_loss: 0.1904 - mrcnn_mask_loss: 0.2642 - val_loss: 1.2048 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.3796 - val_mrcnn_class_loss: 0.2477 - val_mrcnn_bbox_loss: 0.2814 - val_mrcnn_mask_loss: 0.2871
# Epoch 11/30
# 25/25 [==============================] - 96s 4s/step - loss: 0.9011 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2230 - mrcnn_class_loss: 0.2104 - mrcnn_bbox_loss: 0.1920 - mrcnn_mask_loss: 0.2685 - val_loss: 1.1703 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.3519 - val_mrcnn_class_loss: 0.2603 - val_mrcnn_bbox_loss: 0.2757 - val_mrcnn_mask_loss: 0.2738
# Epoch 12/30
# 25/25 [==============================] - 94s 4s/step - loss: 0.8755 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.1983 - mrcnn_class_loss: 0.2219 - mrcnn_bbox_loss: 0.1806 - mrcnn_mask_loss: 0.2678 - val_loss: 1.1243 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3345 - val_mrcnn_class_loss: 0.2741 - val_mrcnn_bbox_loss: 0.2418 - val_mrcnn_mask_loss: 0.2651
# Epoch 13/30
# 25/25 [==============================] - 98s 4s/step - loss: 0.7511 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.1708 - mrcnn_class_loss: 0.1862 - mrcnn_bbox_loss: 0.1413 - mrcnn_mask_loss: 0.2452 - val_loss: 1.1242 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.3174 - val_mrcnn_class_loss: 0.2800 - val_mrcnn_bbox_loss: 0.2502 - val_mrcnn_mask_loss: 0.2685
# Epoch 14/30
# 25/25 [==============================] - 99s 4s/step - loss: 0.8601 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1945 - mrcnn_class_loss: 0.2250 - mrcnn_bbox_loss: 0.1595 - mrcnn_mask_loss: 0.2746 - val_loss: 1.1534 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 0.3488 - val_mrcnn_class_loss: 0.2523 - val_mrcnn_bbox_loss: 0.2734 - val_mrcnn_mask_loss: 0.2707
# Epoch 15/30
# 25/25 [==============================] - 93s 4s/step - loss: 0.7595 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.1848 - mrcnn_class_loss: 0.1780 - mrcnn_bbox_loss: 0.1331 - mrcnn_mask_loss: 0.2571 - val_loss: 1.0693 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3415 - val_mrcnn_class_loss: 0.2376 - val_mrcnn_bbox_loss: 0.2300 - val_mrcnn_mask_loss: 0.2517
# Epoch 16/30
# 25/25 [==============================] - 89s 4s/step - loss: 0.6914 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.1541 - mrcnn_class_loss: 0.1866 - mrcnn_bbox_loss: 0.1115 - mrcnn_mask_loss: 0.2335 - val_loss: 1.1222 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.3620 - val_mrcnn_class_loss: 0.2544 - val_mrcnn_bbox_loss: 0.2385 - val_mrcnn_mask_loss: 0.2591
# Epoch 17/30
# 25/25 [==============================] - 98s 4s/step - loss: 0.7401 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1766 - mrcnn_class_loss: 0.1697 - mrcnn_bbox_loss: 0.1306 - mrcnn_mask_loss: 0.2571 - val_loss: 1.1275 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3537 - val_mrcnn_class_loss: 0.2563 - val_mrcnn_bbox_loss: 0.2470 - val_mrcnn_mask_loss: 0.2628
# Epoch 18/30
# 25/25 [==============================] - 106s 4s/step - loss: 0.6729 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1460 - mrcnn_class_loss: 0.1581 - mrcnn_bbox_loss: 0.1095 - mrcnn_mask_loss: 0.2543 - val_loss: 1.1256 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3407 - val_mrcnn_class_loss: 0.2562 - val_mrcnn_bbox_loss: 0.2534 - val_mrcnn_mask_loss: 0.2677
# Epoch 19/30
# 25/25 [==============================] - 89s 4s/step - loss: 0.6559 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1456 - mrcnn_class_loss: 0.1562 - mrcnn_bbox_loss: 0.1047 - mrcnn_mask_loss: 0.2446 - val_loss: 1.0825 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.3502 - val_mrcnn_class_loss: 0.2379 - val_mrcnn_bbox_loss: 0.2300 - val_mrcnn_mask_loss: 0.2569
# Epoch 20/30
# 25/25 [==============================] - 99s 4s/step - loss: 0.6664 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.1403 - mrcnn_class_loss: 0.1514 - mrcnn_bbox_loss: 0.1242 - mrcnn_mask_loss: 0.2439 - val_loss: 1.1786 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3688 - val_mrcnn_class_loss: 0.2646 - val_mrcnn_bbox_loss: 0.2669 - val_mrcnn_mask_loss: 0.2704
# Epoch 21/30
# 25/25 [==============================] - 92s 4s/step - loss: 0.6830 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.1483 - mrcnn_class_loss: 0.1479 - mrcnn_bbox_loss: 0.1274 - mrcnn_mask_loss: 0.2534 - val_loss: 1.0950 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3445 - val_mrcnn_class_loss: 0.2382 - val_mrcnn_bbox_loss: 0.2449 - val_mrcnn_mask_loss: 0.2598
# Epoch 22/30
# 25/25 [==============================] - 97s 4s/step - loss: 0.5963 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1240 - mrcnn_class_loss: 0.1406 - mrcnn_bbox_loss: 0.0930 - mrcnn_mask_loss: 0.2339 - val_loss: 1.1267 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3679 - val_mrcnn_class_loss: 0.2535 - val_mrcnn_bbox_loss: 0.2346 - val_mrcnn_mask_loss: 0.2631
# Epoch 23/30
# 25/25 [==============================] - 98s 4s/step - loss: 0.6018 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.1268 - mrcnn_class_loss: 0.1322 - mrcnn_bbox_loss: 0.0903 - mrcnn_mask_loss: 0.2476 - val_loss: 1.0600 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.3370 - val_mrcnn_class_loss: 0.2337 - val_mrcnn_bbox_loss: 0.2286 - val_mrcnn_mask_loss: 0.2539
# Epoch 24/30
# 25/25 [==============================] - 98s 4s/step - loss: 0.5498 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1041 - mrcnn_class_loss: 0.1243 - mrcnn_bbox_loss: 0.0939 - mrcnn_mask_loss: 0.2224 - val_loss: 1.0599 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 0.3316 - val_mrcnn_class_loss: 0.2374 - val_mrcnn_bbox_loss: 0.2276 - val_mrcnn_mask_loss: 0.2556
# Epoch 25/30
# 25/25 [==============================] - 89s 4s/step - loss: 0.5363 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1044 - mrcnn_class_loss: 0.1134 - mrcnn_bbox_loss: 0.0844 - mrcnn_mask_loss: 0.2288 - val_loss: 1.0418 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.3172 - val_mrcnn_class_loss: 0.2321 - val_mrcnn_bbox_loss: 0.2341 - val_mrcnn_mask_loss: 0.2516
# Epoch 26/30
# 25/25 [==============================] - 101s 4s/step - loss: 0.5781 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1138 - mrcnn_class_loss: 0.1268 - mrcnn_bbox_loss: 0.0927 - mrcnn_mask_loss: 0.2400 - val_loss: 1.0926 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.3355 - val_mrcnn_class_loss: 0.2349 - val_mrcnn_bbox_loss: 0.2506 - val_mrcnn_mask_loss: 0.2647
# Epoch 27/30
# 25/25 [==============================] - 94s 4s/step - loss: 0.5517 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.1040 - mrcnn_class_loss: 0.1178 - mrcnn_bbox_loss: 0.0829 - mrcnn_mask_loss: 0.2424 - val_loss: 1.0844 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.3471 - val_mrcnn_class_loss: 0.2364 - val_mrcnn_bbox_loss: 0.2379 - val_mrcnn_mask_loss: 0.2558
# Epoch 28/30
# 25/25 [==============================] - 96s 4s/step - loss: 0.5409 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1016 - mrcnn_class_loss: 0.1082 - mrcnn_bbox_loss: 0.0859 - mrcnn_mask_loss: 0.2402 - val_loss: 1.0884 - val_rpn_class_loss: 0.0066 - val_rpn_bbox_loss: 0.3275 - val_mrcnn_class_loss: 0.2375 - val_mrcnn_bbox_loss: 0.2525 - val_mrcnn_mask_loss: 0.2642
# Epoch 29/30
# 25/25 [==============================] - 95s 4s/step - loss: 0.4929 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0860 - mrcnn_class_loss: 0.1021 - mrcnn_bbox_loss: 0.0761 - mrcnn_mask_loss: 0.2238 - val_loss: 1.0783 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.3130 - val_mrcnn_class_loss: 0.2492 - val_mrcnn_bbox_loss: 0.2474 - val_mrcnn_mask_loss: 0.2618
# Epoch 30/30
# 25/25 [==============================] - 101s 4s/step - loss: 0.4662 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0770 - mrcnn_class_loss: 0.0940 - mrcnn_bbox_loss: 0.0660 - mrcnn_mask_loss: 0.2252 - val_loss: 1.0692 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3410 - val_mrcnn_class_loss: 0.2349 - val_mrcnn_bbox_loss: 0.2253 - val_mrcnn_mask_loss: 0.2608

# %% [markdown]
# # Visualize image output

# %%
os.listdir(MODEL_DIR)
# Out:
# ['fruits20200330T1703']

# %%
dir_names = os.listdir(MODEL_DIR)
dir_names = sorted(dir_names)

fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(MODEL_DIR, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else: 
      
      checkpoint = os.path.join(dir_name, checkpoints[-1])
      fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model /content/drive/My Drive/project/logs/fruits20200330T1703/mask_rcnn_fruits_0030.h5

# %% [markdown]
# # Create inference configuration

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights from  /content/drive/My Drive/project/logs/fruits20200330T1703/mask_rcnn_fruits_0030.h5
# Re-starting from epoch 30

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    class_ids = [x - 1 for x in class_ids]
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# # Predict output

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))
start_idx = 0
for i in range(start_idx, start_idx + 3):
    
    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    plt.subplot(6, 2, 2*(i-start_idx) + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*(i-start_idx) + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
